# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 16669 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8) ...
# ...

# %%
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# Out:
# gpg: keybox '/tmp/tmpavfw3uxl/pubring.gpg' created
# gpg: /tmp/tmpavfw3uxl/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# ...

# %%
# !apt-get update -qq 2>&1 > /dev/null

# %%
# !apt-get install -y -qq google-drive-ocamlfuse fuse
# Out:
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 18077 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.6.21-0ubuntu2_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.6.21-0ubuntu2) ...

# %%
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !pip install -q keras

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 12

# %%
# !python3 drive/AI/colab/mnist_cnn.py
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ...
# 11493376/11490434 [==============================] - 1s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 2018-02-20 09:18:00.424638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-02-20 09:18:00.424909: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1208] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...

# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P drive/AI/colab
# Out:
# --2018-02-20 09:28:59--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70366 (69K) [text/plain]
# Saving to: ‘drive/AI/colab/Titanic.csv’
#
# Titanic.csv         100%[===================>]  68.72K   209KB/s    in 0.3s
#
# 2018-02-20 09:29:02 (209 KB/s) - ‘drive/AI/colab/Titanic.csv’ saved [70366/70366]

# %%
import pandas as pd
titanic = pd.read_csv("drive/AI/colab/Titanic.csv")
titanic.head(5)
# Out:
#    Unnamed: 0                                           Name PClass    Age  \
# 0           1                   Allen, Miss Elisabeth Walton    1st  29.00
# 1           2                    Allison, Miss Helen Loraine    1st   2.00
# 2           3            Allison, Mr Hudson Joshua Creighton    1st  30.00
# 3           4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00
# 4           5                  Allison, Master Hudson Trevor    1st   0.92
#
#       Sex  Survived  SexCode
# 0  female         1        1
# 1  female         0        1
# 2    male         0        0
# 3  female         0        1
# 4    male         1        0

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13341960 kB
# MemFree:         3969096 kB
# MemAvailable:   11428460 kB
# Buffers:          647132 kB
# Cached:          6439904 kB
# SwapCached:            0 kB
# Active:          4160588 kB
# Inactive:        4096312 kB
# Active(anon):    1339144 kB
# Inactive(anon):   114428 kB
# Active(file):    2821444 kB
# Inactive(file):  3981884 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               596 kB
# Writeback:             0 kB
# AnonPages:       1169900 kB
# Mapped:           416672 kB
# Shmem:            283720 kB
# Slab:             942160 kB
# SReclaimable:     909452 kB
# SUnreclaim:        32708 kB
# KernelStack:        3824 kB
# PageTables:        10452 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6670980 kB
# Committed_AS:    2960628 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 18336272892583282868, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 356515840
#  locality {
#    bus_id: 1
#  }
#  incarnation: 2992746012833319719
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]
